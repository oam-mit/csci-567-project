# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Preprocessing

# %%
df = pd.read_csv("dataset/train.csv", keep_default_na=False,na_values=["NA", np.nan, ""])

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df = df.drop("Id", axis=1)

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %% [markdown]
# # Data Preprocessing

# %%
df["Alley"] = df["Alley"].fillna("NA")

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['LotFrontage',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
na_columns = ["Alley", "BsmtQual", "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2", "FireplaceQu", "GarageType", "GarageFinish", "GarageQual", "GarageCond", "PoolQC", "Fence", "MiscFeature"]

# %%
df[na_columns] = df[na_columns].fillna("NA")

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['LotFrontage', 'MasVnrType', 'MasVnrArea', 'Electrical', 'GarageYrBlt']

# %%
df["MasVnrType"] = df["MasVnrType"].fillna("None")

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['LotFrontage', 'MasVnrArea', 'Electrical', 'GarageYrBlt']

# %%
def replace_with_mean(df, column):
    mean = df[column].mean()
    df[column] = df[column].fillna(mean)
    return df

# %%
df = replace_with_mean(df, column="LotFrontage")

# %%
df = replace_with_mean(df, column="MasVnrArea")

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['Electrical', 'GarageYrBlt']

# %%
df["Electrical"] = df["Electrical"].fillna("SBrkr")

# %%
df["GarageYrBlt"] = df["GarageYrBlt"].fillna(2005)

# %%
df["Exterior2nd"] = df["Exterior2nd"].replace({"CmentBd": "CemntBd", "Wd Shng" :"WdShing", "Brk Cmn": "BrkComm"})
df["MSZoning"] = df["MSZoning"].replace({"C (all)":"C"})

# %%
df["MSSubClass"].value_counts()
# Out:
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: count, dtype: int64

# %%
MS_SubclassMapping = {20:0, 30:1, 40:2, 45:3, 50:4, 60:5, 70: 6, 75: 7, 80: 8, 85:9, 90: 10, 120: 11, 150: 12, 160: 13, 180: 14, 190: 15}

# %%
MSZoning_Mapping = {"A":0, "C":1, "FV":2, "I":3, "RH":4, "RL":5, "RP":6, "RM":7}

# %%
utilites_map = {"AllPub" : 0, "NoSewr": 1, "NoSeWa":2, "ELO":3}
condition_2_map = {index: key for key, index in enumerate(df["Condition1"].astype("category").cat.categories)}
exterior_list = {index: key for key, index in enumerate(["AsbShng", "AsphShn", "BrkComm", "BrkFace", "CBlock", "CemntBd", "HdBoard", "ImStucc", "MetalSd", "Other", "Plywood", "PreCast", "Stone", "Stucco", "VinylSd", "Wd Sdng", "WdShing"])}
masvnrtype_map = {index:key for key, index in enumerate(["BrkCmn", "BrkFace", "CBlock", "None", "Stone"])}
exterior_quality_map = kitchen_qual_map = {index:key for key, index in enumerate(["Ex", "Gd", "TA", "Fa", "Po"])}
bsmt_quality_map = bsmt_cond_map  = {index:key for key, index in enumerate(["Ex", "Gd", "TA", "Fa", "Po", "NA"])}
functional_map = {index:key for key, index in enumerate(["Typ", "Min1", "Min2", "Mod", "Maj1", "Maj2", "Sev", "Sal"])}
pool_qc_map = {index:key for key, index in enumerate(["Ex", "Gd", "TA", "Fa", "NA"])}
misc_feature_map = {index:key for key, index in enumerate(["Elev", "Gar2", "Othr", "Shed", "TenC", "NA"])}
sales_type_feature_map = {index:key for key, index in enumerate(["WD", "CWD", "VWD", "New", "COD", "Con", "COD", "Con", "ConLw" ,"ConLI", "ConLD", "Oth"])}

# %%
df["Foundation"].value_counts()
# Out:
# Foundation
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: count, dtype: int64

# %%
exterior_list
# Out:
# {'AsbShng': 0,
#  'AsphShn': 1,
#  'BrkComm': 2,
#  'BrkFace': 3,
#  'CBlock': 4,
#  'CemntBd': 5,
#  'HdBoard': 6,
#  'ImStucc': 7,
#  'MetalSd': 8,
#  'Other': 9,
#  'Plywood': 10,
#  'PreCast': 11,
#  'Stone': 12,
#  'Stucco': 13,
#  'VinylSd': 14,
#  'Wd Sdng': 15,
#  'WdShing': 16}

# %%
#df["LotShape"] = df["LotShape"].astype("category")

# %%
df["PavedDrive"].value_counts()
# Out:
# PavedDrive
# Y    1340
# N      90
# P      30
# Name: count, dtype: int64

# %%
def get_proprocessed_data():

    category_list = ["Street", "Alley", "LotShape", "LandContour", "LotConfig", "LandSlope", "BldgType", "HouseStyle", "RoofStyle", "RoofMatl", "ExterCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2", "Heating", "HeatingQC", "CentralAir", "Electrical", "FireplaceQu", "GarageType", "GarageFinish", "GarageQual", "GarageCond", "Fence", "SaleCondition","Neighborhood", "Foundation", "PavedDrive"]
    df["MSSubClass"] = df["MSSubClass"].replace(MS_SubclassMapping)
    df["MSZoning"] = df["MSZoning"].replace(MSZoning_Mapping)
    df["Utilities"] = df["Utilities"].replace(utilites_map)
    df["Condition1"] = df["Condition1"].replace(condition_2_map)
    df["Condition2"] = df["Condition2"].replace(condition_2_map)
    df["Exterior1st"] = df["Exterior1st"].replace(exterior_list)
    df["Exterior2nd"] = df["Exterior2nd"].replace(exterior_list)
    df["MasVnrType"] = df["MasVnrType"].replace(masvnrtype_map)
    df["ExterQual"] = df["ExterQual"].replace(exterior_quality_map)
    df["BsmtQual"] = df["BsmtQual"].replace(bsmt_quality_map)
    df["BsmtCond"] = df["BsmtCond"].replace(bsmt_cond_map)
    df["KitchenQual"] = df["KitchenQual"].replace(kitchen_qual_map)
    df["Functional"] = df["Functional"].replace(functional_map)
    df["PoolQC"] = df["PoolQC"].replace(pool_qc_map)
    df["MiscFeature"] = df["MiscFeature"].replace(misc_feature_map)
    df["SaleType"] = df["SaleType"].replace(sales_type_feature_map)

    for category in category_list:
        df[category] = df[category].astype("category")
        df[category] = df[category].cat.codes

# %%
get_proprocessed_data()
# Out:
# /var/folders/gr/jldz2p6n4k9c6wvsc1fm2lch0000gn/T/ipykernel_71334/1701218584.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["MSZoning"] = df["MSZoning"].replace(MSZoning_Mapping)
# /var/folders/gr/jldz2p6n4k9c6wvsc1fm2lch0000gn/T/ipykernel_71334/1701218584.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Utilities"] = df["Utilities"].replace(utilites_map)
# ...

# %%
df["Condition1"]
# Out:
# 0       2
# 1       1
# 2       2
# 3       2
# 4       2
#        ..
# 1455    2
# 1456    2
# 1457    2
# 1458    2
# 1459    2
# Name: Condition1, Length: 1460, dtype: int64

# %%
df["MiscVal"]
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 1455       0
# 1456       0
# 1457    2500
# 1458       0
# 1459       0
# Name: MiscVal, Length: 1460, dtype: int64

# %%
df["Exterior2nd"].value_counts()
# Out:
# Exterior2nd
# 14    504
# 8     214
# 6     207
# 15    197
# 10    142
# 5      60
# 16     38
# 13     26
# 3      25
# 0      20
# 7      10
# 2       7
# 12      5
# 1       3
# 9       1
# 4       1
# Name: count, dtype: int64

# %% [markdown]
# ## Training

# %%
X = df.drop("SalePrice", axis=1)
Y = df["SalePrice"]

# %%
from sklearn.linear_model import LinearRegression

# %%
classifier = LinearRegression()

# Step 4: Train the classifier
classifier.fit(X, Y)
# Out:
# LinearRegression()

# %%
pd.set_option('display.max_columns', None)

# %%
column_types = df.dtypes.tolist()
print(column_types)
# Out:
# [dtype('int64'), dtype('O'), dtype('float64'), dtype('int64'), dtype('int8'), dtype('int8'), dtype('int8'), dtype('int8'), dtype('int64'), dtype('int8'), dtype('int8'), dtype('O'), dtype('O'), dtype('O'), dtype('int8'), dtype('int8'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int8'), dtype('int8'), dtype('O'), dtype('O'), dtype('int64'), dtype('float64'), dtype('int64'), dtype('int8'), dtype('O'), dtype('int64'), dtype('int64'), dtype('int8'), dtype('int8'), dtype('int64'), dtype('int8'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int8'), dtype('int8'), dtype('int8'), dtype('int8'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int8'), dtype('int8'), dtype('float64'), dtype('int8'), dtype('int64'), dtype('int64'), dtype('int8'), dtype('int8'), dtype('O'), dtype(
# ...

# %%
df.to_csv('output.csv', index=False)
